# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '79b3fbee-1d17-4b8f-9186-e8945f58186d',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-04-28T13:48:04.779Z', 'error_code': 0, 'error_message': None, 'elapsed': 62, 'credit_count': 1, 'notice': None, 'total_count': 9433}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10196, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19358475, 'total_supply': 19358475, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-04-28T13:46:00.000Z', 'quote': {'USD': {'price': 28938.01175200333, 'volume_24h': 22162574679.164948, 'volume_change_24h': -29.3387, 'percent_change_1h': -1.32068891, 'percent_change_24h': 0.24279511, 'percent_change_7d': 2.33797035, 'percent_change_30d': 2.05832521, 'percent_change_60d': 21.86504248, 'percent_change_90d': 26.00881957, 'market_cap': 560195777050.8627, 'market_cap_dominance': 46.8702, 'fully_diluted_market_cap': 607698246792.07, 'tvl': None, 'last_updated': '2023-04-28T13:46:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6797, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120400464.2666373, 'total_supply': 120400464.2666373, 'infinite_supply': False, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-04-28T13:46:00.000Z', 'quote': {'USD': {'price': 1885.7083722610591, 'volume_24h': 10841529809.956486, 'volume_change_24h': -28.3385, 'percent_change_1h': -1.08502139, 'percent_change_24h': 0.34602822, 'percent_change_7d': -1.84213822, 'percent_change_30d': 4.37443635, 'percent_change_60d': 13.57278446, 'percent_change_90d': 19.854432, 'market_cap': 227040163491.71643, 'market_cap_dominance': 18.9945, 'fully_diluted_market_cap': 227040163491.72, 'tvl': None, 'last_updated': '2023-04-28T13:46:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 52247, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 81615536097.75209, 'total_supply': 85090638896.27086, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 's ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])

df['timestamp'] = pd.to_datetime('now',utc=True)

df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10196
# 1   1027     Ethereum    ETH      ethereum              6797
# 2    825       Tether   USDT        tether             52247
# 3   1839          BNB    BNB           bnb              1298
# 4   3408     USD Coin   USDC      usd-coin             12074
# 5     52          XRP    XRP           xrp               939
# 6   2010      Cardano    ADA       cardano               773
# 7     74     Dogecoin   DOGE      dogecoin               697
# 8   3890      Polygon  MATIC       polygon               675
# 9   5426       Solana    SOL        solana               458
# 10  6636     Polkadot    DOT  polkadot-new               499
# 11     2     Litecoin    LTC      litecoin               909
# 12  4687  Binance USD   BUSD   binance-usd              6673
# 13  5994    Shiba Inu   SHIB     shiba-inu               508
# 14  1958         TRON    TRX          tron               754
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2019-09-20T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14                  [media, payments, tron-ecosystem]           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.935848e+07  1.935848e+07            False       NaN         1
# 1         1.204005e+08  1.204005e+08            False       NaN         2
# 2         8.161554e+10  8.509064e+10            False       NaN         3
# 3         1.558632e+08  1.558632e+08            False       NaN         4
# 4         3.052596e+10  3.052596e+10            False       NaN         5
# 5         5.175081e+10  9.998900e+10            False       NaN         6
# 6         3.480231e+10  3.572784e+10            False       NaN         7
# 7         1.391244e+11  1.391244e+11            False       NaN         8
# 8         9.249469e+09  1.000000e+10            False       NaN         9
# 9         3.930269e+08  5.393127e+08            False       NaN        10
# 10        1.178109e+09  1.307588e+09            False       NaN        11
# 11        7.280340e+07  8.400000e+07            False       NaN        12
# 12        6.280952e+09  6.280952e+09            False       NaN        13
# 13        5.895438e+14  5.896048e+14            False       NaN        14
# 14        9.064978e+10  9.064982e+10            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                      7.165966e+10              4.708959e+09      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-04-28T13:46:00.000Z     28938.011752          2.216257e+10
# 1   2023-04-28T13:46:00.000Z      1885.708372          1.084153e+10
# 2   2023-04-28T13:46:00.000Z         1.000468          3.150319e+10
# 3   2023-04-28T13:46:00.000Z       320.978485          1.097984e+09
# 4   2023-04-28T13:46:00.000Z         1.000074          4.603478e+09
# 5   2023-04-28T13:46:00.000Z         0.467940          1.664345e+09
# 6   2023-04-28T13:46:00.000Z         0.399804          3.163486e+08
# 7   2023-04-28T13:46:00.000Z         0.079473          3.070457e+08
# 8   2023-04-28T13:46:00.000Z         0.985158          4.602633e+08
# 9   2023-04-28T13:46:00.000Z        22.312532          4.204940e+08
# 10  2023-04-28T13:46:00.000Z         5.810542          1.603844e+08
# 11  2023-04-28T13:46:00.000Z        88.451117          4.707883e+08
# 12  2023-04-28T13:46:00.000Z         1.000384          3.224524e+09
# 13  2023-04-28T13:46:00.000Z         0.000010          9.872590e+07
# 14  2023-04-28T13:46:00.000Z         0.065713          1.736545e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -29.3387                    -1.320689
# 1                      -28.3385                    -1.085021
# 2                      -27.7207                    -0.001417
# 3                       23.9272                    -0.654473
# 4                      -29.3046                     0.004444
# 5                        9.2970                    -1.006020
# 6                      -38.4906                    -1.165293
# 7                      -56.1747                    -0.804611
# 8                      -28.2541                    -1.022730
# 9                      -39.5606                    -1.446203
# 10                     -35.0609                    -0.935803
# 11                     -40.6305                    -1.077782
# 12                     -23.8788                     0.040065
# 13                     -48.9726                    -0.761405
# 14                     -29.6702                    -0.626351
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.242795                     2.337970
# 1                       0.346028                    -1.842138
# 2                       0.009861                     0.050575
# 3                      -2.468439                    -2.312935
# 4                       0.006824                    -0.010267
# 5                       2.184946                    -0.364291
# 6                      -2.448692                    -1.041073
# 7                       0.078914                    -5.715348
# 8                      -0.682421                    -6.008798
# 9                       3.406471                     0.262227
# 10                     -1.473280                    -4.593341
# 11                      0.162449                    -1.733299
# 12                      0.017510                     0.055644
# 13                     -0.621505                    -4.469083
# 14                      0.118150                    -0.330415
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       2.058325                     21.865042
# 1                       4.374436                     13.572784
# 2                       0.033548                      0.036276
# 3                       1.359399                      4.596373
# 4                       0.018155                     -0.011705
# 5                     -14.787096                     23.804786
# 6                       3.596680                      9.041752
# 7                       4.649600                     -2.788195
# 8                     -13.113579                    -22.478635
# 9                       5.335546                     -3.996358
# 10                     -6.709608                    -13.366397
# 11                     -3.071802                     -7.316309
# 12                      0.056796                      0.042148
# 13                     -5.330353                    -20.593675
# 14                      1.613740                     -4.813488
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      26.008820          5.601958e+11
# 1                      19.854432          2.270402e+11
# 2                       0.024642          8.165377e+10
# 3                       5.415945          5.002872e+10
# 4                       0.010647          3.052821e+10
# 5                      14.754010          2.421625e+10
# 6                       4.731067          1.391411e+10
# 7                      -9.676083          1.105670e+10
# 8                     -11.274558          9.112191e+09
# 9                      -6.784652          8.769426e+09
# 10                     -9.077234          6.845455e+09
# 11                      0.939692          6.439542e+09
# 12                      0.040161          6.283363e+09
# 13                    -13.677266          5.990193e+09
# 14                      5.182933          5.956854e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          46.8702                        6.076982e+11
# 1                          18.9945                        2.270402e+11
# 2                           6.8254                        8.513050e+10
# 3                           4.1855                        5.002872e+10
# 4                           2.5518                        3.052821e+10
# 5                           2.0107                        4.679395e+10
# 6                           1.1558                        1.799119e+10
# 7                           0.9251                        1.105670e+10
# 8                           0.7624                        9.851583e+09
# 9                           0.7285                        1.203343e+10
# 10                          0.5727                        7.597798e+09
# 11                          0.5388                        7.429894e+09
# 12                          0.5219                        6.283363e+09
# 13                          0.5011                        5.990812e+09
# 14                          0.4984                        5.956856e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 1           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 2           None  2023-04-28T13:46:00.000Z       1027.0      Ethereum
# 3           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 4           None  2023-04-28T13:46:00.000Z       1027.0      Ethereum
# 5           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 6           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 7           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 8           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 9           None  2023-04-28T13:46:00.000Z          NaN           NaN
# 10          None  2023-04-28T13:46:00.000Z          NaN           NaN
# 11          None  2023-04-28T13:46:00.000Z          NaN           NaN
# 12          None  2023-04-28T13:46:00.000Z       1839.0           BNB
# 13          None  2023-04-28T13:46:00.000Z       1027.0      Ethereum
# 14          None  2023-04-28T13:46:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             BNB           bnb                                    BUSD-BD1
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                           timestamp
# 0  2023-04-28 13:49:32.663663+00:00
# 1  2023-04-28 13:49:32.663663+00:00
# 2  2023-04-28 13:49:32.663663+00:00
# 3  2023-04-28 13:49:32.663663+00:00
# 4  2023-04-28 13:49:32.663663+00:00
# 5  2023-04-28 13:49:32.663663+00:00
# 6  2023-04-28 13:49:32.663663+00:00
# 7  2023-04-28 13:49:32.663663+00:00
# 8  2023-04-28 13:49:32.663663+00:00
# 9  2023-04-28 13:49:32.663663+00:00
# 10 2023-04-28 13:49:32.663663+00:00
# 11 2023-04-28 13:49:32.663663+00:00
# 12 2023-04-28 13:49:32.663663+00:00
# 13 2023-04-28 13:49:32.663663+00:00
# 14 2023-04-28 13:49:32.663663+00:00

# %%
# Run API function

def api_runner():
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '79b3fbee-1d17-4b8f-9186-e8945f58186d',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now',utc=True)
    df = df2.append(df2)
    
      df_append = pd.DataFrame(df2)
    df = pd.concat([df2,df_append])

# %%
import os
from time import time
from time import sleep


for i in range(333):
    api_runner()
    print('API Runnner Completed')
    sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2023-04-28T13:59:07.356Z', 'error_code': 0, 'error_message': None, 'elapsed': 448, 'credit_count': 1, 'notice': None, 'total_count': 9433}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10196, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19358475, 'total_supply': 19358475, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-04-28T13:57:00.000Z', 'quote': {'USD': {'price': 28995.340373621326, 'volume_24h': 22360500231.836834, 'volume_change_24h': -28.5272, 'percent_change_1h': -0.95911257, 'percent_change_24h': 0.16586082, 'percent_change_7d': 3.10220519, 'percent_change_30d': 2.10355406, 'percent_change_60d': 22.15265876, 'percent_change_90d': 26.17560901, 'market_cap': 561305571739.2391, 'market_cap_dominance': 47.049, 'fully_diluted_market_cap': 608902147846.05, 'tvl': None, 'last_updated': '2023-04-28T13:57:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6797, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120400464.2666373, 'total_supply': 120400464.2666373, 'infinite_supply': False, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-04-28T13:57:00.000Z', 'quote': {'USD': {'price': 1886.2731729873929, 'volume_24h': 10889319670.991447, 'volume_change_24h': -28.0086, 'percent_change_1h': -0.78578129, 'percent_change_24h': 0.09411723, 'percent_change_7d': -1.26282222, 'percent_change_30d': 4.27792822, 'percent_change_60d': 13.55983401, 'percent_change_90d': 19.76522551, 'market_cap': 227108165761.38513, 'market_cap_dominance': 19.0323, 'fully_diluted_market_cap': 227108165761.39, 'tvl': None, 'last_updated': '2023-04-28T13:57:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 52248, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 81615536097.75209, 'total_supply': 85090638896.27086, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', ...
# API Runnner Completed
# C:\Users\ffpin\AppData\Local\Temp\ipykernel_6056\2038712139.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df2.append(df2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 9
#       7     api_runner()
#       8     print('API Runnner Completed')
# ----> 9     sleep(60)
#      10 exit()
#
# KeyboardInterrupt:
